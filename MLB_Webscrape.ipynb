# %% [markdown]
# # Webscrape the 2024 MLB Regular Season Schedule

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Get schedule information

# %%
response = requests.get("https://www.baseball-reference.com/leagues/majors/2024-schedule.shtml")
if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html5lib")
    days = soup.find("div", {"class": "section_content"}).find_all("div")
    games = []
    for day in days:

        date = day.find("h3")
        todays_games = day.find_all("p", {"class": "game"})

        for game in todays_games:

            current_game = {}
            current_game["date"] = date.text

            teams = game.find_all("a")
            time =  game.find("strong")
            away_team = teams[0].text
            home_team = teams[1].text

            current_game["away"] = away_team
            current_game["home"] = home_team
            current_game["time"] = time.text

            games.append(current_game)

# %%
# save schedule information to a dataframe
data = pd.DataFrame(games)
data
# Out:
#                             date                 away                   home  \
# 0      Wednesday, March 20, 2024  Los Angeles Dodgers       San Diego Padres
# 1       Thursday, March 21, 2024     San Diego Padres    Los Angeles Dodgers
# 2         Friday, March 22, 2024      Minnesota Twins         Tampa Bay Rays
# 3         Friday, March 22, 2024       Detroit Tigers  Philadelphia Phillies
# 4         Friday, March 22, 2024        New York Mets       New York Yankees
# ...                          ...                  ...                    ...
# 2494  Sunday, September 29, 2024        New York Mets      Milwaukee Brewers
# 2495  Sunday, September 29, 2024    Baltimore Orioles        Minnesota Twins
# 2496  Sunday, September 29, 2024    Oakland Athletics       Seattle Mariners
# 2497  Sunday, September 29, 2024   Kansas City Royals         Atlanta Braves
# 2498  Sunday, September 29, 2024      Cincinnati Reds           Chicago Cubs
#
#                             time
# 0      Los Angeles Dodgers\n (5)
# 1        San Diego Padres\n (15)
# 2                        1:05 pm
# 3                        1:05 pm
# 4                        1:05 pm
# ...                          ...
# 2494                     3:10 pm
# 2495                     3:10 pm
# 2496                     3:10 pm
# 2497                     3:20 pm
# 2498                     3:20 pm
#
# [2499 rows x 4 columns]

# %%
data.drop(index=[0, 1], axis=0, inplace=True)  # remove spring training games
data = data.reset_index()
data = data[["date", "away", "home", "time"]]
data
# Out:
#                             date                away                   home  \
# 0         Friday, March 22, 2024     Minnesota Twins         Tampa Bay Rays
# 1         Friday, March 22, 2024      Detroit Tigers  Philadelphia Phillies
# 2         Friday, March 22, 2024       New York Mets       New York Yankees
# 3         Friday, March 22, 2024      Atlanta Braves        Minnesota Twins
# 4         Friday, March 22, 2024      Boston Red Sox      Toronto Blue Jays
# ...                          ...                 ...                    ...
# 2492  Sunday, September 29, 2024       New York Mets      Milwaukee Brewers
# 2493  Sunday, September 29, 2024   Baltimore Orioles        Minnesota Twins
# 2494  Sunday, September 29, 2024   Oakland Athletics       Seattle Mariners
# 2495  Sunday, September 29, 2024  Kansas City Royals         Atlanta Braves
# 2496  Sunday, September 29, 2024     Cincinnati Reds           Chicago Cubs
#
#          time
# 0     1:05 pm
# 1     1:05 pm
# 2     1:05 pm
# 3     1:05 pm
# 4     1:07 pm
# ...       ...
# 2492  3:10 pm
# 2493  3:10 pm
# 2494  3:10 pm
# 2495  3:20 pm
# 2496  3:20 pm
#
# [2497 rows x 4 columns]

# %% [markdown]
# ## Get stadium information

# %%
response = requests.get("https://www.mlb.com/team")
if response.status_code == 200:
    addresses_home = BeautifulSoup(response.text, "html5lib")
    stadiums = addresses_home.find_all("div", {"class": "p-forge-list-item l-grid__content l-grid__content--card t-none u-app-hide"})
    team_stadiums = []
    for stadium in stadiums:
        team_name = stadium.find("h2", {"class": "p-heading__text p-heading__text--lined p-heading__text--center p-heading__text--h5 styles-sc-zrz8sa-0 bFNgUm"}).text
        raw_address = str(stadium.find("p")).split("<br/>Phone")[0]  # .get_text().split("Phone:")[0]
        stadium_name = raw_address.split("<br/>")[1]
        street = raw_address.split("<br/>")[1]
        city = raw_address.split("<br/>")[-1]
        address = street + ", " + city
        city = city.rsplit(" ", 1)[0]

        team_stadiums.append({"team": team_name, "stadium": stadium_name, "address": address, "city": city, "street": street})

# %%
stadium_data = pd.DataFrame(team_stadiums)
stadium_data
# Out:
#                      team                        stadium  \
# 0    Arizona Diamondbacks      401 East Jefferson Street
# 1          Atlanta Braves             755 Battery Avenue
# 2       Baltimore Orioles         333 West Camden Street
# 3          Boston Red Sox                4 Jersey Street
# 4            Chicago Cubs              1060 West Addison
# 5       Chicago White Sox           333 West 35th Street
# 6         Cincinnati Reds                100 Main Street
# 7     Cleveland Guardians            2401 Ontario Street
# 8        Colorado Rockies              2001 Blake Street
# 9          Detroit Tigers           2100 Woodward Avenue
# 10         Houston Astros            501 Crawford Street
# 11     Kansas City Royals                  One Royal Way
# 12     Los Angeles Angels            2000 Gene Autry Way
# 13    Los Angeles Dodgers         1000 Vin Scully Avenue
# 14          Miami Marlins                501 Marlins Way
# 15      Milwaukee Brewers                One Brewers Way
# 16        Minnesota Twins                    1 Twins Way
# 17          New York Mets                  41 Seaver Way
# 18       New York Yankees          One East 161st Street
# 19      Oakland Athletics              7000 Coliseum Way
# 20  Philadelphia Phillies          One Citizens Bank Way
# 21     Pittsburgh Pirates             115 Federal Street
# 22       San Diego Padres             100 Park Boulevard
# 23   San Francisco Giants           24 Willie Mays Plaza
# 24       Seattle Mariners                  P.O. Box 4100
# 25    St. Louis Cardinals               700 Clark Street
# 26         Tampa Bay Rays            One Tropicana Drive
# 27          Texas Rangers              734 Stadium Drive
# 28      Toronto Blue Jays    1 Blue Jays Way, Suite 3200
# 29   Washington Nationals  1500 South Capitol Street, SE
#
#                                               address  \
# 0        401 East Jefferson Street, Phoenix, AZ 85004
# 1               755 Battery Avenue, Atlanta, GA 30339
# 2         333 West Camden Street, Baltimore, MD 21201
# 28  Toronto, Ontario, Canada    1 Blue Jays Way, Suite 3200
# 29            Washington, DC  1500 South Capitol Street, SE

# %% [markdown]
# ## Combine schedule and stadium information

# %%
merged = data.merge(stadium_data, how = "left", left_on = "home", right_on = "team").drop("team", axis=1)
merged
# Out:
#                             date                away                   home  \
# 0         Friday, March 22, 2024     Minnesota Twins         Tampa Bay Rays
# 1         Friday, March 22, 2024      Detroit Tigers  Philadelphia Phillies
# 2         Friday, March 22, 2024       New York Mets       New York Yankees
# 3         Friday, March 22, 2024      Atlanta Braves        Minnesota Twins
# 4         Friday, March 22, 2024      Boston Red Sox      Toronto Blue Jays
# ...                          ...                 ...                    ...
# 2492  Sunday, September 29, 2024       New York Mets      Milwaukee Brewers
# 2493  Sunday, September 29, 2024   Baltimore Orioles        Minnesota Twins
# 2494  Sunday, September 29, 2024   Oakland Athletics       Seattle Mariners
# 2495  Sunday, September 29, 2024  Kansas City Royals         Atlanta Braves
# 2496  Sunday, September 29, 2024     Cincinnati Reds           Chicago Cubs
#
#          time                      stadium  \
# 0     1:05 pm          One Tropicana Drive
# 1     1:05 pm        One Citizens Bank Way
# 2     1:05 pm        One East 161st Street
# 3     1:05 pm                  1 Twins Way
# 4     1:07 pm  1 Blue Jays Way, Suite 3200
# ...       ...                          ...
# 2492  3:10 pm              One Brewers Way
# 2493  3:10 pm                  1 Twins Way
# 2494  3:10 pm                P.O. Box 4100
# 2495  3:20 pm           755 Battery Avenue
# 2496  3:20 pm            1060 West Addison
#
#                                                 address  \
# 0         One Tropicana Drive, St. Petersburg, FL 33705
# 1         One Citizens Bank Way, Philadelphia, PA 19148
# 2                One East 161st Street, Bronx, NY 10451
# 3                    1 Twins Way, Minneapolis, MN 55403
# 4     1 Blue Jays Way, Suite 3200, Toronto, Ontario,...
# ...                                                 ...
# 2492               One Brewers Way, Milwaukee, WI 53214
# 2493                 1 Twins Way, Minneapolis, MN 55403
# 2494                   P.O. Box 4100, Seattle, WA 98104
# 2495              755 Battery Avenue, Atlanta, GA 30339
# 2496          1060 West Addison, Chicago, IL 60613-4397
#
#                           city                       street
# 0           St. Petersburg, FL          One Tropicana Drive
# 1             Philadelphia, PA        One Citizens Bank Way
# 2                    Bronx, NY        One East 161st Street
# 3              Minneapolis, MN                  1 Twins Way
# 4     Toronto, Ontario, Canada  1 Blue Jays Way, Suite 3200
# ...                        ...                          ...
# 2492             Milwaukee, WI              One Brewers Way
# 2493           Minneapolis, MN                  1 Twins Way
# 2494               Seattle, WA                P.O. Box 4100
# 2495               Atlanta, GA           755 Battery Avenue
# 2496               Chicago, IL            1060 West Addison
#
# [2497 rows x 8 columns]

# %%
# save the data to a CSV
merged.to_csv("MLB_Schedule_2024.csv", columns=list(merged.columns))
